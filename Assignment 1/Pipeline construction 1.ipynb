# %%
import pandas as pd
import numpy as np
import pylab as pl
import Pipeline.util as u
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-6c61aa51be6e> in <module>()
#       2 import numpy as np
#       3 import pylab as pl
# ----> 4 import Pipeline.util as u
#
# ModuleNotFoundError: No module named 'Pipeline.util'

# %%
data = pd.read_csv('data/credit-data.csv')

# %%
from pandas.types.common import is_numeric_dtype
is_numeric_dtype(data.SeriousDlqin2yrs)
# Out:
# True

# %%
pd.value_counts(data.SeriousDlqin2yrs).plot(kind='bar')
pl.show()

# %%
# Out:
# 0.066839999999999997

# %%
data.describe().ix[:,1:]
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#              zipcode  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean    60648.810013                              0.421033     353.005076
# ...

# %%
import Pipeline.process as pr
data = pd.read_csv('data/credit-data.csv')

# %%
data2=fill_with_mean(data,"MonthlyIncome")
data2["MonthlyIncome"].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 149970    False
# 149971    False
# 149972    False
# 149973    False
# 149974    False
# 149975    False
# 149976    False
# 149977    False
# 149978    False
# 149979    False
# 149980    False
# 149981    False
# 149982    False
# 149983    False
# 149984    False
# 149985    False
# 149986    False
# 149987    False
# 149988    False
# 149989    False
# 149990    False
# 149991    False
# 149992    False
# 149993    False
# ...

# %%
data[["DebtRatio","MonthlyIncome"]].fillna(data[["DebtRatio","MonthlyIncome"]].mean())
# Out:
#           DebtRatio  MonthlyIncome
# 0          0.802982    9120.000000
# 1          0.121876    2600.000000
# 2          0.085113    3042.000000
# 3          0.036050    3300.000000
# 4          0.024926   63588.000000
# 5          0.375607    3500.000000
# 6       5710.000000    6670.221237
# 7          0.209940    3500.000000
# 8         46.000000    6670.221237
# 9          0.606291   23684.000000
# 10         0.309476    2500.000000
# 11         0.531529    6501.000000
# 12         0.298354   12454.000000
# 13         0.382965   13700.000000
# 14       477.000000       0.000000
# 15         0.209892   11362.000000
# 16      2058.000000    6670.221237
# 17         0.188274    8800.000000
# 18         0.527888    3280.000000
# 19         0.065868     333.000000
# 20         0.430046   12300.000000
# 21         0.475841    3000.000000
# 22         0.241104    2500.000000
# 23         0.085512    7916.000000
# 24         0.241622    2416.000000
# 25         1.595253    4676.000000
# ...
